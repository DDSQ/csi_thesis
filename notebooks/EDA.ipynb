# %%
import pandas as pd

import matplotlib
import seaborn as sns

# %%
fixation = pd.read_csv("/data/EyelinkChangeBlindness/AggregatedData/fixations.csv")

# %% [markdown]
# EDA. numerical

# %%
fixation.info() # checking the variable names and the datatypes.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10527 entries, 0 to 10526
# Data columns (total 14 columns):
# Image            10527 non-null int64
# ROI              10527 non-null int64
# Participant      10527 non-null int64
# FixDur           10527 non-null int64
# Start            10527 non-null int64
# End              10527 non-null int64
# X                10527 non-null float64
# Y                10527 non-null float64
# Group            10527 non-null object
# Name             10527 non-null object
# ChangedObject    10527 non-null object
# Movable          10527 non-null object
# Evidence         10527 non-null object
# ExitEntry        10527 non-null object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 1.1+ MB

# %%
fixation.describe() # summary statistics
# Out:
#               Image           ROI   Participant        FixDur         Start  \
# count  10527.000000  10527.000000  10527.000000  10527.000000  10527.000000
# mean       7.055476      5.519521    447.474494    354.585732  11537.325069
# std        3.920204      5.304089    489.987841    219.399937   9450.158001
# min        1.000000      0.000000      1.000000     21.000000    -29.000000
# 25%        4.000000      0.000000      6.000000    206.000000   3443.500000
# 50%        8.000000      5.000000    102.000000    304.000000   8943.000000
# 75%       10.000000     10.000000   1013.000000    450.000000  18381.500000
# max       14.000000     27.000000   1020.000000   4820.000000  40482.000000
#
#                 End             X             Y
# count  10527.000000  10527.000000  10527.000000
# mean   11890.910801    520.778018    381.557205
# std     9448.204660    155.076364    104.309122
# min       45.000000   -111.700000   -128.700000
# ...

# %%
plt.figure()
sns.countplot( x = ')

# %%
# Out:
#    Image  ROI  Participant  FixDur  Start   End      X      Y   Group  \
# 0      1    0            1     157      7   163  485.3  396.6  Novice
# 1      1    0            1     138    197   334  466.9  322.5  Novice
# 2      1    8            1     517    377   893  606.7  341.0  Novice
# 3      1    7            1     303    935  1237  513.9  413.0  Novice
# 4      1    8            1     248   1260  1507  543.9  372.2  Novice
#
#         Name ChangedObject Movable Evidence ExitEntry
# 0  Elsewhere            No      No       No        No
# 1  Elsewhere            No      No       No        No
# 2      jeans            No     Yes       No        No
# 3    blanket            No     Yes       No        No
# 4      jeans            No     Yes       No        No
