# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
import glob
from sklearn.utils import resample

import seaborn as sns
import matplotlib.image as mpimg
from PIL import Image
from sklearn.decomposition import PCA

from functools import reduce

import modules as m

import warnings
warnings.filterwarnings("ignore")
plt.style.use('ggplot')

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import LeaveOneOut
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier

from sklearn import metrics

# %%
cd /Users/decio/thesis/csi_thesis
# Out:
# /Users/decio/thesis/csi_thesis

# %%
cb = pd.read_csv("/Users/decio/thesis/csi_thesis/data/external/EyelinkChangeBlindness/AggregatedData/fixations.csv")

# %%
cb = cb[cb.Image == 1].loc[:,['ROI','FixDur', 'Group']] #.groupby(['Image','ROI','Group','Evidence']).count()

# %%
cbone = cb[cb.ROI.isin([4,12,13])].groupby(['ROI','Group']).count().reset_index() #these are the ROIs that are evidence.

# %%
cbone.to_csv('relfixcbone.csv')

# %%
# now for image 5

# %%
cbive = cb[cb.Image == 5].loc[:,['ROI','FixDur', 'Group', 'Evidence']] #.groupby(['Image','ROI','Group','Evidence']).count()

# %%
cbive_no = cbive[cbive.Evidence == 'No'].drop(['Evidence'], 
                                    axis = 1).groupby(['ROI','Group']).count().reset_index()

# %%
cbive2.to_csv('cbive.csv')

# %%
cbive_no.to_csv('cbive_no.csv')

# %%
cbive
# Out:
#        ROI  FixDur   Group Evidence
# 159      0     247  Novice       No
# 160      0     163  Novice       No
# 161      9     501  Novice      Yes
# 162     12     593  Novice      Yes
# 163      0     413  Novice       No
# 164      0     462  Novice       No
# 165      0     575  Novice       No
# 166     13     175  Novice       No
# 167      0     422  Novice       No
# 168     17     579  Novice       No
# 169      0     489  Novice       No
# 170      0     581  Novice       No
# 171     19     222  Novice       No
# 172     13     133  Novice       No
# 173     13     150  Novice       No
# 174     13     589  Novice       No
# 175      0     218  Novice       No
# 176     19     160  Novice       No
# 177     13     343  Novice       No
# 178      0     176  Novice       No
# 179      0     346  Novice       No
# 180     12     190  Novice      Yes
# 181     12     104  Novice      Yes
# 182     13     274  Novice       No
# 183      9     202  Novice      Yes
# ...
